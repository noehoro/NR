# %%
import pandas as pd

# Load the CSV file
file_path = './final_agg_data.csv'

# Read the CSV file
df = pd.read_csv(file_path)

# Display basic information about the DataFrame
print("DataFrame Information:")
print(df.info())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicate_rows}")

# Check for anomalies or outliers in key columns
# Adjust the columns in the list below as per your dataset
key_columns = ['diversity', 'tons', 'FAH', 'FAFH', 'Total nominal food sales', 'NUMBER_OF_EVENTS', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS']

print("\nAnomalies/Outliers Check:")
for column in key_columns:
    print(f"\nColumn: {column}")
    print(f"Minimum value: {df[column].min()}")
    print(f"Maximum value: {df[column].max()}")

# Optional: Display descriptive statistics
print("\nDescriptive Statistics:")
print(df[key_columns].describe())
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1875 entries, 0 to 1874
# Data columns (total 33 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Name                                             1875 non-null   object
#  1   State                                            1875 non-null   object
#  2   YEAR                                             1875 non-null   int64
#  3   Region_type                                      1875 non-null   object
#  4   FAH                                              1875 non-null   float64
#  5   FAFH                                             1875 non-null   float64
#  6   Total nominal food sales                         1875 non-null   float64
#  7   FAH.1                                            1875 non-null   object
#  8   FAFH.1                                           1875 non-null   object
#  9   Total constant dollar food sales                 1875 non-null   float64
#  10  NUMBER_OF_EVENTS                                 1875 non-null   int64
#  11  DAMAGE_PROPERTY                                  1875 non-null   float64
#  12  DAMAGE_CROPS                                     1875 non-null   float64
#  13  diversity                                        1875 non-null   float64
#  14  tons                                             1875 non-null   float64
#  15  FAH_diff                                         1875 non-null   float64
#  16  FAH_percent_change                               1875 non-null   float64
#  17  FAFH_diff                                        1875 non-null   float64
#  18  FAFH_percent_change                              1875 non-null   float64
#  19  Total nominal food sales_diff                    1875 non-null   float64
#  20  Total nominal food sales_percent_change          1875 non-null   float64
#  21  Total constant dollar food sales_diff            1875 non-null   float64
#  22  Total constant dollar food sales_percent_change  1875 non-null   float64
#  23  NUMBER_OF_EVENTS_diff                            1875 non-null   float64
#  24  NUMBER_OF_EVENTS_percent_change                  1875 non-null   float64
#  25  DAMAGE_PROPERTY_diff                             1875 non-null   float64
#  26  DAMAGE_PROPERTY_percent_change                   1875 non-null   float64
#  27  DAMAGE_CROPS_diff                                1875 non-null   float64
#  28  DAMAGE_CROPS_percent_change                      1747 non-null   float64
#  29  diversity_diff                                   1875 non-null   float64
#  30  diversity_percent_change                         1875 non-null   float64
#  31  tons_diff                                        1875 non-null   float64
#  32  tons_percent_change                              1875 non-null   float64
# dtypes: float64(26), int64(2), object(5)
# memory usage: 483.5+ KB
# None
#
# Missing Values:
# Name                                                 0
# State                                                0
# YEAR                                                 0
# Region_type                                          0
# FAH                                                  0
# FAFH                                                 0
# Total nominal food sales                             0
# FAH.1                                                0
# FAFH.1                                               0
# Total constant dollar food sales                     0
# NUMBER_OF_EVENTS                                     0
# DAMAGE_PROPERTY                                      0
# DAMAGE_CROPS                                         0
# diversity                                            0
# tons                                                 0
# FAH_diff                                             0
# FAH_percent_change                                   0
# FAFH_diff                                            0
# FAFH_percent_change                                  0
# Total nominal food sales_diff                        0
# Total nominal food sales_percent_change              0
# Total constant dollar food sales_diff                0
# Total constant dollar food sales_percent_change      0
# NUMBER_OF_EVENTS_diff                                0
# NUMBER_OF_EVENTS_percent_change                      0
# DAMAGE_PROPERTY_diff                                 0
# DAMAGE_PROPERTY_percent_change                       0
# DAMAGE_CROPS_diff                                    0
# DAMAGE_CROPS_percent_change                        128
# diversity_diff                                       0
# diversity_percent_change                             0
# tons_diff                                            0
# tons_percent_change                                  0
# dtype: int64
#
# Number of duplicate rows: 0
#
# Anomalies/Outliers Check:
#
# Column: diversity
# Minimum value: 0.1568246663070144
# Maximum value: 0.8050268449756031
#
# Column: tons
# Minimum value: 0.0916042682829191
# Maximum value: 126465.23664674458
#
# Column: FAH
# Minimum value: 1205.91
# Maximum value: 86767.08
#
# Column: FAFH
# Minimum value: 1095.42
# Maximum value: 95228.44
#
# Column: Total nominal food sales
# Minimum value: 2301.34
# Maximum value: 181995.52
#
# Column: NUMBER_OF_EVENTS
# Minimum value: 144
# Maximum value: 5278
#
# Column: DAMAGE_PROPERTY
# Minimum value: 371000.0
# Maximum value: 2142740070.0
#
# Column: DAMAGE_CROPS
# Minimum value: 0.0
# Maximum value: 2247948100.0
#
# Descriptive Statistics:
#          diversity           tons           FAH          FAFH  \
# count  1875.000000    1875.000000   1875.000000   1875.000000
# mean      0.573781    3552.373483  22916.808795  22108.576597
# std       0.113004    9075.942218  20214.531885  21145.998076
# min       0.156825       0.091604   1205.910000   1095.420000
# 25%       0.507803     458.678855  10167.750000   8547.420000
# 50%       0.595453    1478.607623  15652.640000  13795.290000
# 75%       0.655942    3330.166152  26493.350000  24741.250000
# max       0.805027  126465.236647  86767.080000  95228.440000
#
#        Total nominal food sales  NUMBER_OF_EVENTS  DAMAGE_PROPERTY  \
# count               1875.000000       1875.000000     1.875000e+03
# mean               45025.385259       1460.193600     2.179917e+08
# std                41291.792675       1061.189119     4.778610e+08
# min                 2301.340000        144.000000     3.710000e+05
# 25%                19139.700000        878.000000     1.283903e+07
# 50%                29779.750000       1237.000000     4.287550e+07
# 75%                50956.980000       1712.000000     1.120882e+08
# max               181995.520000       5278.000000     2.142740e+09
#
#        DAMAGE_CROPS
# count  1.875000e+03
# mean   1.012321e+08
# std    3.777022e+08
# min    0.000000e+00
# 25%    5.000000e+03
# 50%    1.590000e+05
# 75%    2.040000e+06
# max    2.247948e+09
