# %%
import pandas as pd

# Load the CSV file
file_path = './final_data.csv'

# Read the CSV file
df = pd.read_csv(file_path)

# %%
# Deleting the 'ID' and 'State_FIPS' columns
df.drop(['ID', 'State_FIPS'], axis=1, inplace=True)

# Setting 'Name' and 'YEAR' as the new primary key
df.set_index(['Name', 'State', 'YEAR'], inplace=True)

# Ensure the DataFrame is sorted by the index for correct diff calculations
df.sort_index(inplace=True)

# Calculating the difference for each metric and adding new columns for percentage change
metrics = ['FAH', 'FAFH', 'Total nominal food sales', 'Total constant dollar food sales', 
           'NUMBER_OF_EVENTS', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'diversity', 'tons']

for metric in metrics:
    df[f'{metric}_diff'] = df.groupby(level=0)[metric].diff()  # Difference from previous year
    df[f'{metric}_percent_change'] = df.groupby(level=0)[metric].pct_change() * 100  # Percentage change

# Removing rows with the year 2012
df = df[df.index.get_level_values('YEAR') != 2012]

# Saving the modified DataFrame to a CSV file
df.to_csv('modified_data.csv')

# %%
# Out:
#          Name Region_type  State  YEAR       FAH      FAFH  \
# 528   Abilene         MSA  TEXAS  2012  56284.10  47263.71
# 1153  Abilene         MSA  TEXAS  2013  57944.13  51265.36
# 1778  Abilene         MSA  TEXAS  2014  61201.71  57007.11
# 2403  Abilene         MSA  TEXAS  2015  62350.08  62135.25
# 432     Akron         CSA   OHIO  2012  25043.29  21068.27
#
#       Total nominal food sales      FAH.1     FAFH.1  \
# 528                  103547.81  28,315.20  24,189.32
# 1153                 109209.48  28,889.19  25,688.78
# 1778                 118208.81  29,801.38  27,887.53
# 2403                 124485.33  30,010.40  29,551.13
# 432                   46111.57  12,598.69  10,782.63
#
#       Total constant dollar food sales  ...         tons  diversity_year_diff  \
# 528                           52504.52  ...   909.464031             0.000000
# 1153                          54577.97  ...   923.243490            -0.016197
# 1778                          57688.91  ...   983.125641             0.014650
# 2403                          59561.52  ...   988.576859            -0.000020
# 432                           23381.32  ...  2708.629900             0.000000
#
#       tons_year_diff  FAH_year_diff  FAFH_year_diff  \
# 528         0.000000           0.00            0.00
# 1153       13.779459        1660.03         4001.65
# 1778       59.882150        3257.58         5741.75
# 2403        5.451218        1148.37         5128.14
# 432         0.000000           0.00            0.00
#
#       Total nominal food sales_year_diff  \
# 528                                 0.00
# 1153                             5661.67
# 1778                             8999.33
# 2403                             6276.52
# 432                                 0.00
#
#       Total constant dollar food sales_year_diff  NUMBER_OF_EVENTS_year_diff  \
# 528                                         0.00                         0.0
# 1153                                     2073.45                       455.0
# 1778                                     3110.94                      -561.0
# 2403                                     1872.61                       570.0
# 432                                         0.00                         0.0
#
#       DAMAGE_PROPERTY_year_diff  DAMAGE_CROPS_year_diff
# 528                0.000000e+00            0.000000e+00
# 1153              -8.252347e+08            9.658206e+08
# 1778              -3.845434e+08           -2.123663e+09
# 2403               1.116585e+09            3.316701e+08
# 432                0.000000e+00            0.000000e+00
#
# [5 rows x 24 columns]

# %%
# Display basic information about the DataFrame
print("DataFrame Information:")
print(df.info())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicate_rows}")

# Check for anomalies or outliers in key columns
# Adjust the columns in the list below as per your dataset
key_columns = ['diversity', 'tons', 'FAH', 'FAFH', 'Total nominal food sales', 'NUMBER_OF_EVENTS', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS']

print("\nAnomalies/Outliers Check:")
for column in key_columns:
    print(f"\nColumn: {column}")
    print(f"Minimum value: {df[column].min()}")
    print(f"Maximum value: {df[column].max()}")

# Optional: Display descriptive statistics
print("\nDescriptive Statistics:")
print(df[key_columns].describe())
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1875 entries, ('Abilene', 'TEXAS', 2013) to ('Zanesville', 'OHIO', 2015)
# Data columns (total 30 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Region_type                                      1875 non-null   object
#  1   FAH                                              1875 non-null   float64
#  2   FAFH                                             1875 non-null   float64
#  3   Total nominal food sales                         1875 non-null   float64
#  4   FAH.1                                            1875 non-null   object
#  5   FAFH.1                                           1875 non-null   object
#  6   Total constant dollar food sales                 1875 non-null   float64
#  7   NUMBER_OF_EVENTS                                 1875 non-null   int64
#  8   DAMAGE_PROPERTY                                  1875 non-null   float64
#  9   DAMAGE_CROPS                                     1875 non-null   float64
#  10  diversity                                        1875 non-null   float64
#  11  tons                                             1875 non-null   float64
#  12  FAH_diff                                         1875 non-null   float64
#  13  FAH_percent_change                               1875 non-null   float64
#  14  FAFH_diff                                        1875 non-null   float64
#  15  FAFH_percent_change                              1875 non-null   float64
#  16  Total nominal food sales_diff                    1875 non-null   float64
#  17  Total nominal food sales_percent_change          1875 non-null   float64
#  18  Total constant dollar food sales_diff            1875 non-null   float64
#  19  Total constant dollar food sales_percent_change  1875 non-null   float64
#  20  NUMBER_OF_EVENTS_diff                            1875 non-null   float64
#  21  NUMBER_OF_EVENTS_percent_change                  1875 non-null   float64
#  22  DAMAGE_PROPERTY_diff                             1875 non-null   float64
#  23  DAMAGE_PROPERTY_percent_change                   1875 non-null   float64
#  24  DAMAGE_CROPS_diff                                1875 non-null   float64
#  25  DAMAGE_CROPS_percent_change                      1747 non-null   float64
#  26  diversity_diff                                   1875 non-null   float64
#  27  diversity_percent_change                         1875 non-null   float64
#  28  tons_diff                                        1875 non-null   float64
#  29  tons_percent_change                              1875 non-null   float64
# dtypes: float64(26), int64(1), object(3)
# memory usage: 469.2+ KB
# None
#
# Missing Values:
# Region_type                                          0
# FAH                                                  0
# FAFH                                                 0
# Total nominal food sales                             0
# FAH.1                                                0
# FAFH.1                                               0
# Total constant dollar food sales                     0
# NUMBER_OF_EVENTS                                     0
# DAMAGE_PROPERTY                                      0
# DAMAGE_CROPS                                         0
# diversity                                            0
# tons                                                 0
# FAH_diff                                             0
# FAH_percent_change                                   0
# FAFH_diff                                            0
# FAFH_percent_change                                  0
# Total nominal food sales_diff                        0
# Total nominal food sales_percent_change              0
# Total constant dollar food sales_diff                0
# Total constant dollar food sales_percent_change      0
# NUMBER_OF_EVENTS_diff                                0
# NUMBER_OF_EVENTS_percent_change                      0
# DAMAGE_PROPERTY_diff                                 0
# DAMAGE_PROPERTY_percent_change                       0
# DAMAGE_CROPS_diff                                    0
# DAMAGE_CROPS_percent_change                        128
# diversity_diff                                       0
# diversity_percent_change                             0
# tons_diff                                            0
# tons_percent_change                                  0
# dtype: int64
#
# Number of duplicate rows: 888
#
# Anomalies/Outliers Check:
#
# Column: diversity
# Minimum value: 0.1568246663070144
# Maximum value: 0.8050268449756031
#
# Column: tons
# Minimum value: 0.0916042682829191
# Maximum value: 126465.23664674458
#
# Column: FAH
# Minimum value: 1205.91
# Maximum value: 86767.08
#
# Column: FAFH
# Minimum value: 1095.42
# Maximum value: 95228.44
#
# Column: Total nominal food sales
# Minimum value: 2301.34
# Maximum value: 181995.52
#
# Column: NUMBER_OF_EVENTS
# Minimum value: 144
# Maximum value: 5278
#
# Column: DAMAGE_PROPERTY
# Minimum value: 371000.0
# Maximum value: 2142740070.0
#
# Column: DAMAGE_CROPS
# Minimum value: 0.0
# Maximum value: 2247948100.0
#
# Descriptive Statistics:
#          diversity           tons           FAH          FAFH  \
# count  1875.000000    1875.000000   1875.000000   1875.000000
# mean      0.573781    3552.373483  22916.808795  22108.576597
# std       0.113004    9075.942218  20214.531885  21145.998076
# min       0.156825       0.091604   1205.910000   1095.420000
# 25%       0.507803     458.678855  10167.750000   8547.420000
# 50%       0.595453    1478.607623  15652.640000  13795.290000
# 75%       0.655942    3330.166152  26493.350000  24741.250000
# max       0.805027  126465.236647  86767.080000  95228.440000
#
#        Total nominal food sales  NUMBER_OF_EVENTS  DAMAGE_PROPERTY  \
# count               1875.000000       1875.000000     1.875000e+03
# mean               45025.385259       1460.193600     2.179917e+08
# std                41291.792675       1061.189119     4.778610e+08
# min                 2301.340000        144.000000     3.710000e+05
# 25%                19139.700000        878.000000     1.283903e+07
# 50%                29779.750000       1237.000000     4.287550e+07
# 75%                50956.980000       1712.000000     1.120882e+08
# max               181995.520000       5278.000000     2.142740e+09
#
#        DAMAGE_CROPS
# count  1.875000e+03
# mean   1.012321e+08
# std    3.777022e+08
# min    0.000000e+00
# 25%    5.000000e+03
# 50%    1.590000e+05
# 75%    2.040000e+06
# max    2.247948e+09
